# %% [markdown]
# # EE Hyperparameter Tuning for Benchmarks
#
# - ***Execute on Google Colab***
# - ***Execute all the cells below for the first time***

# %% [markdown]
# ## Step 1: Configure Runtime

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')

# install bayesian optimization without logs
# !pip install bayesian-optimization > /dev/null
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Step 2: Execute Main Program

# %%
# %cd '/content/drive/My Drive/Colab Notebooks/EE/bayesopt/benchmarks/src'
# !python3 './main.py' 'sphere' 'momentum'
# Out:
# /content/drive/My Drive/Colab Notebooks/EE/bayesopt/benchmarks/src
# float128
# float128
# float128
# float128
# float128
# float128
# float128
# float128
# float128
# float128
# float128
# /content/drive/My Drive/Colab Notebooks/EE/bayesopt/benchmarks/src/optimization.py:74: RuntimeWarning: divide by zero encountered in log10
#   return float(np.log10(min(dists_ave))) * (-1.0)
# float128
# float128
# float128
# float128
# float128
# float128
# float128
# float128
# float128
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/bayes_opt/bayesian_optimization.py", line 179, in maximize
#     x_probe = next(self._queue)
#   File "/usr/local/lib/python3.6/dist-packages/bayes_opt/bayesian_optimization.py", line 25, in __next__
#     raise StopIteration("Queue is empty, no more objects to retrieve.")
# StopIteration: Queue is empty, no more objects to retrieve.
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# %cd '/content/drive/My Drive/Colab Notebooks/EE/bayesopt/benchmarks/src'
# for benchmark_name in ('ackley', 'bukin', 'eclipse', 'levi', 'rastrigin', 'rosenbrock', 'sphere'):
#     for optimizer_name in ('adadelta', 'adagrad', 'adam', 'adamax', 'momentum', 'nadam', 'nesterov', 'rmsprop', 'sgd'):
for benchmark_name in ('rosenbrock', 'sphere'):
    for optimizer_name in ('adadelta', 'adagrad', 'adam', 'adamax', 'momentum', 'nadam', 'nesterov', 'rmsprop', 'sgd'):
        print(benchmark_name, optimizer_name)
        # !python3 './main.py' $benchmark_name $optimizer_name

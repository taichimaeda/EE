# %% [markdown]
# # EE Network Hyperparameter Optimization

# %% [markdown]
# ## Configure Runtime

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')

# install hyperopt
# !pip install hyperopt > /dev/null

# install hyperdash and login
# taichi.maeda.up@gmail.com
# Ud8JZPVT
# !pip install hyperdash > /dev/null
# !hd login --email

# %% [markdown]
# ## Execute Main Program

# %%
# %%capture
# %cd '/content/drive/My Drive/Colab Notebooks/EE/hyperopt/networks/src'

from optimization import Optimization

dataset_name = 'imdb'
model_name = 'lstm'
# for optimizer_name in ('adadelta', 'adagrad', 'adam', 'adamax', 'momentum', 'nadam', 'nesterov', 'rmsprop', 'sgd'):
optimizer_name = 'nesterov'
optimization = Optimization(dataset_name, model_name, optimizer_name)
optimization.begin()

# %% [markdown]
# # EE Benchmark Hyperparameter Optimization

# %% [markdown]
# ## Configure Runtime

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')

# install hyperopt
# !pip install hyperopt > /dev/null
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Execute Main Program

# %%
# %cd '/content/drive/My Drive/Colab Notebooks/EE/hyperopt/benchmarks/src'

from optimization import Optimization

# for benchmark_name in ('ackley', 'bukin', 'levi', 'rastrigin', 'rosenbrock'):
#     for optimizer_name in ('adadelta', 'adagrad', 'adam', 'adamax', 'momentum', 'nadam', 'nesterov', 'rmsprop', 'sgd'):
benchmark_name = 'levi'
optimizer_name = 'adagrad'
optimization = Optimization(benchmark_name, optimizer_name)
optimization.begin()
# Out:
# /content/drive/My Drive/Colab Notebooks/EE/hyperopt/benchmarks/src
# 100%|██████████| 200/200 [01:50<00:00,  1.82it/s, best loss: 0.1388242774194073]
